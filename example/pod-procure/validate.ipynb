# %%
from cwltool.main import main as cwlmain
from cwltool.process import use_custom_schema
import argparse
from io import StringIO
import cwltool
import re

# %%
# cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE = re.compile(r".*")
# cwltool.command_line_tool.ACCEPTLIST_RE = cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE

# %%
# print(cwltool.process.supportedProcessRequirements)

# %%
with open("schema.yaml") as f:
    schema_content = f.read()

# %%
use_custom_schema("v1.2", "https://calrissian-cwl.github.io/#", schema_content)

# %%
# cwltool.process.supportedProcessRequirements.append("https://dask.org/cwl#DaskGatewayRequirement")

# print(cwltool.process.supportedProcessRequirements)

# %%
def add_arv_hints():
    cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE = re.compile(r".*")
    cwltool.command_line_tool.ACCEPTLIST_RE = cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE
    supported_versions = ["v1.0", "v1.1", "v1.2"]
    
    with open("schema.yaml") as f:
        schema_content = f.read()
    
    for s in supported_versions:
        use_custom_schema(s, "https://calrissian-cwl.github.io/#", schema_content)
    
    cwltool.process.supportedProcessRequirements.extend([
        "https://calrissian-cwl.github.io/#DaskGatewayRequirement"
    ])

add_arv_hints()

parsed_args = argparse.Namespace(
    validate=True,
    fast_parser=False,
    enable_ext=True,
    workflow="example.cwl",
    custom_schema_callback=add_arv_hints,
)

# %%
stream_out = StringIO()
stream_err = StringIO()

res = cwlmain(
    args=parsed_args,
    stdout=stream_out,
)

# %%
print(stream_out.getvalue())
# Out:
# INFO /data/work/github-fbrito/dev-platform-dask-gateway/example/pod-procure/.env/lib/python3.13/site-packages/ipykernel_launcher.py 3.1.20250110105449
# INFO Resolved 'example.cwl' to 'file:///data/work/github-fbrito/dev-platform-dask-gateway/example/pod-procure/example.cwl'
# ERROR Tool definition failed validation:
# example.cwl:3:1:   Object 'example.cwl#example' is not valid because
#                     tried 'CommandLineTool' but
# example.cwl:12:1:     the 'requirements' field is not valid because
#                         tried array of <InlineJavascriptRequirement or SchemaDefRequirement or
#                         LoadListingRequirement or DockerRequirement or SoftwareRequirement or
#                         InitialWorkDirRequirement or EnvVarRequirement or ShellCommandRequirement or
#                         ResourceRequirement or WorkReuse or NetworkAccess or InplaceUpdateRequirement or
#                         ToolTimeLimit or SubworkflowFeatureRequirement or ScatterFeatureRequirement or
#                         MultipleInputFeatureRequirement or StepInputExpressionRequirement or Secrets or
#                         MPIRequirement or CUDARequirement or Loop or ShmSize> but
# example.cwl:13:3:         item is invalid because
#                             - tried InlineJavascriptRequirement but
#                               Expected class 'org.w3id.cwl.cwl.InlineJavascriptRequirement' but
#                               this is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried SchemaDefRequirement but
#                               Expected class 'org.w3id.cwl.cwl.SchemaDefRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried LoadListingRequirement but
#                               Expected class 'org.w3id.cwl.cwl.LoadListingRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried DockerRequirement but
#                               Expected class 'org.w3id.cwl.cwl.DockerRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried SoftwareRequirement but
#                               Expected class 'org.w3id.cwl.cwl.SoftwareRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried InitialWorkDirRequirement but
#                               Expected class 'org.w3id.cwl.cwl.InitialWorkDirRequirement' but this
#                               is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried EnvVarRequirement but
#                               Expected class 'org.w3id.cwl.cwl.EnvVarRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried ShellCommandRequirement but
#                               Expected class 'org.w3id.cwl.cwl.ShellCommandRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried ResourceRequirement but
#                               Expected class 'org.w3id.cwl.cwl.ResourceRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried WorkReuse but
#                               Expected class 'org.w3id.cwl.cwl.WorkReuse' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried NetworkAccess but
#                               Expected class 'org.w3id.cwl.cwl.NetworkAccess' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried InplaceUpdateRequirement but
#                               Expected class 'org.w3id.cwl.cwl.InplaceUpdateRequirement' but this
#                               is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried ToolTimeLimit but
#                               Expected class 'org.w3id.cwl.cwl.ToolTimeLimit' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried SubworkflowFeatureRequirement but
#                               Expected class 'org.w3id.cwl.cwl.SubworkflowFeatureRequirement' but
#                               this is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried ScatterFeatureRequirement but
#                               Expected class 'org.w3id.cwl.cwl.ScatterFeatureRequirement' but this
#                               is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried MultipleInputFeatureRequirement but
#                               Expected class 'org.w3id.cwl.cwl.MultipleInputFeatureRequirement' but
#                               this is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried StepInputExpressionRequirement but
#                               Expected class 'org.w3id.cwl.cwl.StepInputExpressionRequirement' but
#                               this is 'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried Secrets but
#                               Expected class 'org.commonwl.cwltool.Secrets' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried MPIRequirement but
#                               Expected class 'org.commonwl.cwltool.MPIRequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried CUDARequirement but
#                               Expected class 'org.commonwl.cwltool.CUDARequirement' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried Loop but
#                               Expected class 'org.commonwl.cwltool.Loop' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
#                             - tried ShmSize but
#                               Expected class 'org.commonwl.cwltool.ShmSize' but this is
#                               'https://calrissian-cwl.github.io/#DaskGatewayRequirement'
