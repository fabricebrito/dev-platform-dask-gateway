# %%
from cwltool.main import main as cwlmain
from cwltool.process import use_custom_schema
import argparse
from io import StringIO
import cwltool
import re

# %%
# cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE = re.compile(r".*")
# cwltool.command_line_tool.ACCEPTLIST_RE = cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE

# %%
# print(cwltool.process.supportedProcessRequirements)
# Out:
# ['DockerRequirement', 'SchemaDefRequirement', 'EnvVarRequirement', 'ScatterFeatureRequirement', 'SubworkflowFeatureRequirement', 'MultipleInputFeatureRequirement', 'InlineJavascriptRequirement', 'ShellCommandRequirement', 'StepInputExpressionRequirement', 'ResourceRequirement', 'InitialWorkDirRequirement', 'ToolTimeLimit', 'WorkReuse', 'NetworkAccess', 'InplaceUpdateRequirement', 'LoadListingRequirement', 'http://commonwl.org/cwltool#MPIRequirement', 'http://commonwl.org/cwltool#TimeLimit', 'http://commonwl.org/cwltool#WorkReuse', 'http://commonwl.org/cwltool#NetworkAccess', 'http://commonwl.org/cwltool#LoadListingRequirement', 'http://commonwl.org/cwltool#InplaceUpdateRequirement', 'http://commonwl.org/cwltool#CUDARequirement', 'http://commonwl.org/cwltool#ShmSize']

# %%
with open("schema.yaml") as f:
    schema_content = f.read()

# %%
#use_custom_schema("v1.2", "https://dask.org/cwl", schema_content)

# %%
# cwltool.process.supportedProcessRequirements.append("https://dask.org/cwl#DaskGatewayRequirement")

# print(cwltool.process.supportedProcessRequirements)
# Out:
# ['DockerRequirement', 'SchemaDefRequirement', 'EnvVarRequirement', 'ScatterFeatureRequirement', 'SubworkflowFeatureRequirement', 'MultipleInputFeatureRequirement', 'InlineJavascriptRequirement', 'ShellCommandRequirement', 'StepInputExpressionRequirement', 'ResourceRequirement', 'InitialWorkDirRequirement', 'ToolTimeLimit', 'WorkReuse', 'NetworkAccess', 'InplaceUpdateRequirement', 'LoadListingRequirement', 'http://commonwl.org/cwltool#MPIRequirement', 'http://commonwl.org/cwltool#TimeLimit', 'http://commonwl.org/cwltool#WorkReuse', 'http://commonwl.org/cwltool#NetworkAccess', 'http://commonwl.org/cwltool#LoadListingRequirement', 'http://commonwl.org/cwltool#InplaceUpdateRequirement', 'http://commonwl.org/cwltool#CUDARequirement', 'http://commonwl.org/cwltool#ShmSize', 'https://dask.org/cwl#DaskGatewayRequirement']

# %%
def add_arv_hints():
    cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE = re.compile(r".*")
    cwltool.command_line_tool.ACCEPTLIST_RE = cwltool.command_line_tool.ACCEPTLIST_EN_RELAXED_RE
    supported_versions = ["v1.0", "v1.1", "v1.2"]
    
    with open("schema.yaml") as f:
        schema_content = f.read()
    
    for s in supported_versions:
        use_custom_schema(s, "https://dask.org/cwl", schema_content)
    
    cwltool.process.supportedProcessRequirements.extend([
        "https://dask.org/cwl#DaskGatewayRequirement"
    ])

add_arv_hints()

parsed_args = argparse.Namespace(
    validate=True,
    fast_parser=True,
    workflow="example.cwl",
    #custom_schema_callback=add_arv_hints,
)

# %%
stream_out = StringIO()
stream_err = StringIO()

res = cwlmain(
    args=parsed_args,
    stdout=stream_out,
)
# Out:
# INFO /data/work/github-fbrito/dev-platform-dask-gateway/example/pod-procure/.env/lib/python3.13/site-packages/ipykernel_launcher.py 3.1.20241112140730
# INFO Resolved 'example.cwl' to 'file:///data/work/github-fbrito/dev-platform-dask-gateway/example/pod-procure/example.cwl'
# ERROR Tool definition failed validation:
# example.cwl:3:1:   Object `example.cwl` is not valid because:
# example.cwl:12:1:   the `requirements` field is not valid because:
#                       Expected a <class 'NoneType'> but got list

# %%
print(stream_out.getvalue())
